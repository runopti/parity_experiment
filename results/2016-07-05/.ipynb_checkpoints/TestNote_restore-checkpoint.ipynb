# %%
import tensorflow as tf
import numpy as np
import math

# %%
from tensorflow.python import ops
from tensorflow.core.framework import graph_pb2
from google.protobuf import text_format

# %% [markdown]
# - Load the variables

# %%
#new_saver = tf.train.Saver()
with tf.Session() as sess:
    new_saver = tf.train.import_meta_graph('./hidden-uni-vis-test-2016-07-07-09:10:05/my_model-0.meta')
    #print(new_saver.GraphDef())
    new_saver.restore(sess, './hidden-uni-vis-test-2016-07-07-09:10:05/my_model-0')
    #print(ops.get_default_graph().as_graph_def())
    #graph_def = ops.get_default_graph().as_graph_def()
    var_dict = {}
    var_name_list = []
    for var in tf.trainable_variables():
        print(var.value().name)
        print(var.eval())
        var_dict[var.value().name] = sess.run(var) #tf.constant(var.eval())  # was just var.name before
        var_name_list.append(var.value().name)
# Out:
# in/Variable/read:0
# [[ 4.80228472]]
# in/Variable_1/read:0
# [-2.34548235]
# BasicRNNCell/Linear/Matrix/read:0
# [[-3.96679235]
#  [ 9.02636147]]
# BasicRNNCell/Linear/Bias/read:0
# [ 0.13169986]
# out/Variable/read:0
# [[-0.39107317 -1.57618523]]
# out/Variable_1/read:0
# [ 0.42867854  1.40981781]
# in_1/Variable/read:0
# [[-3.51048779]]
# in_1/Variable_1/read:0
# [-0.07502892]
# out_1/Variable/read:0
# [[-1.30552268 -0.25459343]]
# out_1/Variable_1/read:0
# [-0.97308564 -0.54189807]
# in_2/Variable/read:0
# [[-4.54929304]]
# in_2/Variable_1/read:0
# [ 0.03087632]
# out_2/Variable/read:0
# [[ 1.17908645 -1.56300735]]
# out_2/Variable_1/read:0
# [-1.36001205  1.28313386]

# %%
var_dict["out/Variable/read:0"]
# Out:
# array([[-0.39107317, -1.57618523]], dtype=float32)

# %%
from easydict import EasyDict as edict
args = edict({'hidden_size':1, 'batch_size':1, 'output_size': 2, 'seq_len': 4, 'train_method': "single", 'max_grad_norm':5.0, 'grad_clip': True})

# %%
hidden_size = args.hidden_size # 2 # 4
batch_size = args.batch_size #1
output_size = args.output_size  #2
seq_len = args.seq_len  #12 #3  #6

# %%
graph_new1 = tf.Graph()
with graph_new1.as_default():
    ############## Graph construction ################
    data = tf.placeholder(tf.float32, shape=[batch_size, seq_len])
    if args.train_method == "single":
        target = tf.placeholder(tf.float32, shape=[batch_size, output_size])
    else:
        target = tf.placeholder(tf.float32, shape=[seq_len, batch_size, output_size])
        target_list = [tf.squeeze(tf.slice(target, [i,0,0], [1, batch_size, output_size])) for i in range(seq_len)]
    learning_rate = tf.placeholder(tf.float32, shape=[])

    lstm = tf.nn.rnn_cell.BasicRNNCell(hidden_size)
    # initialize the state
    initial_state = state = tf.zeros([batch_size, hidden_size])

    for i in range(seq_len):
        if i > 0: tf.get_variable_scope().reuse_variables()
        with tf.name_scope("in") as scope:
            weights = tf.Variable(tf.truncated_normal([hidden_size, batch_size], stddev=1.0/math.sqrt(float(hidden_size)), name="weights"))
            biases = tf.Variable(tf.truncated_normal([hidden_size], stddev=1.0/math.sqrt(float(hidden_size)), name="biases"))
            mapped = weights *  data[:,i]
            mapped = tf.reshape(mapped, [1, hidden_size]) # 1 x hidden_size
            mapped = mapped + biases
            #mapped = tf.Print(mapped, [mapped], message="this is mapped: ")
        cell_output, state = lstm(mapped, state)
        with tf.name_scope("out") as scope:
            weights = tf.Variable(tf.truncated_normal([hidden_size, output_size], stddev=1.0/math.sqrt(float(hidden_size)), name="weights"))
            biases = tf.Variable(tf.truncated_normal([output_size], stddev=1.0/math.sqrt(float(hidden_size)), name="biases"))
            output = tf.nn.softmax(tf.matmul(cell_output, weights) + biases)  # the size of output should be just [batch_size, 1] right?
            #output = tf.reshape(output, [1,2])
        if args.train_method == "single":                                                    
            pass
        else:
            # target has to be shape=[seq_len * [1,2]]
            loss_per_digit = -tf.reduce_sum(target_list[i]*tf.log(output)) # this should be just 1 by 1 - 1 by 1            
            if args.grad_clip:
                tvars = tf.trainable_variables()
                grads, _ = tf.clip_by_global_norm(tf.gradients(loss_per_digit, tvars), args.max_grad_norm)
                optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
                train_op = optimizer.apply_gradients(zip(grads, tvars))
            else:
                train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

    if args.train_method == "single":
        loss = -tf.reduce_sum(target*tf.log(output)) # this should be just 1 by 1 - 1 by 1
        tf.scalar_summary("loss", loss)
        #train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
        if args.grad_clip:
            tvars = tf.trainable_variables()
            grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), args.max_grad_norm)
            #optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
            optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
            train_op = optimizer.apply_gradients(zip(grads, tvars))
        else:
            train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss) # 0.001
    else:
        loss = tf.identity(loss_per_digit)
    
    init_op = tf.initialize_all_variables()
    ############### Graph construction end ##########

# %%
new_graph_def = graph_new1.as_graph_def()

# %%
var_dict
# Out:
# {'BasicRNNCell/Linear/Bias/read:0': array([ 0.13169986], dtype=float32),
#  'BasicRNNCell/Linear/Matrix/read:0': array([[-3.96679235],
#         [ 9.02636147]], dtype=float32),
#  'in/Variable/read:0': array([[ 4.80228472]], dtype=float32),
#  'in/Variable_1/read:0': array([-2.34548235], dtype=float32),
#  'in_1/Variable/read:0': array([[-3.51048779]], dtype=float32),
#  'in_1/Variable_1/read:0': array([-0.07502892], dtype=float32),
#  'in_2/Variable/read:0': array([[-4.54929304]], dtype=float32),
#  'in_2/Variable_1/read:0': array([ 0.03087632], dtype=float32),
#  'out/Variable/read:0': array([[-0.39107317, -1.57618523]], dtype=float32),
#  'out/Variable_1/read:0': array([ 0.42867854,  1.40981781], dtype=float32),
#  'out_1/Variable/read:0': array([[-1.30552268, -0.25459343]], dtype=float32),
#  'out_1/Variable_1/read:0': array([-0.97308564, -0.54189807], dtype=float32),
#  'out_2/Variable/read:0': array([[ 1.17908645, -1.56300735]], dtype=float32),
#  'out_2/Variable_1/read:0': array([-1.36001205,  1.28313386], dtype=float32)}

# %%
# restoring variables
with graph_new1.as_default():
    new_graph_def = graph_new1.as_graph_def()
    #for node in new_graph_def.node:
     #   print(node)
    dummy_var = np.float32(np.repeat(2.0,1).reshape(1,1))
    tf.import_graph_def(new_graph_def, input_map={"in/Variable/read:0" : dummy_var })
    new_graph_def1 = graph_new1.as_graph_def()
    #for node in new_graph_def.node:
     #   if node.op == 'Variable':
          #print(node)

# %%
new_graph_def2 = graph_new1.as_graph_def()
for node in new_graph_def2.node:
    if node.op == 'Variable':
        print(node.name)
        print(node.attr['value'].tensor)
# Out:
# in/Variable
#
# in/Variable_1
#
# BasicRNNCell/Linear/Matrix
#
# BasicRNNCell/Linear/Bias
#
# out/Variable
#
# out/Variable_1
#
# in_1/Variable
#
# in_1/Variable_1
#
# out_1/Variable
#
# out_1/Variable_1
#
# in_2/Variable
#
# in_2/Variable_1
#
# out_2/Variable
#
# out_2/Variable_1
#
# in_3/Variable
#
# in_3/Variable_1
#
# out_3/Variable
#
# out_3/Variable_1
#
# beta1_power
#
# beta2_power
#
# in/Variable/Adam
#
# in/Variable/Adam_1
#
# in/Variable_1/Adam
#
# in/Variable_1/Adam_1
#
# BasicRNNCell/Linear/Matrix/Adam
#
# BasicRNNCell/Linear/Matrix/Adam_1
#
# BasicRNNCell/Linear/Bias/Adam
#
# BasicRNNCell/Linear/Bias/Adam_1
#
# in_1/Variable/Adam
#
# in_1/Variable/Adam_1
#
# in_1/Variable_1/Adam
#
# in_1/Variable_1/Adam_1
#
# in_2/Variable/Adam
#
# in_2/Variable/Adam_1
#
# in_2/Variable_1/Adam
#
# in_2/Variable_1/Adam_1
#
# in_3/Variable/Adam
#
# in_3/Variable/Adam_1
#
# in_3/Variable_1/Adam
#
# in_3/Variable_1/Adam_1
#
# out_3/Variable/Adam
#
# out_3/Variable/Adam_1
#
# out_3/Variable_1/Adam
#
# out_3/Variable_1/Adam_1
#
# import/in/Variable
#
# import/in/Variable_1
#
# import/BasicRNNCell/Linear/Matrix
#
# import/BasicRNNCell/Linear/Bias
#
# import/out/Variable
#
# import/out/Variable_1
#
# import/in_1/Variable
#
# import/in_1/Variable_1
#
# import/out_1/Variable
#
# import/out_1/Variable_1
#
# import/in_2/Variable
#
# import/in_2/Variable_1
#
# import/out_2/Variable
#
# import/out_2/Variable_1
#
# import/in_3/Variable
#
# import/in_3/Variable_1
#
# import/out_3/Variable
#
# import/out_3/Variable_1
#
# import/beta1_power
#
# import/beta2_power
#
# import/in/Variable/Adam
#
# import/in/Variable/Adam_1
#
# import/in/Variable_1/Adam
#
# import/in/Variable_1/Adam_1
#
# import/BasicRNNCell/Linear/Matrix/Adam
#
# import/BasicRNNCell/Linear/Matrix/Adam_1
#
# import/BasicRNNCell/Linear/Bias/Adam
#
# import/BasicRNNCell/Linear/Bias/Adam_1
#
# import/in_1/Variable/Adam
#
# import/in_1/Variable/Adam_1
#
# import/in_1/Variable_1/Adam
#
# import/in_1/Variable_1/Adam_1
#
# import/in_2/Variable/Adam
#
# import/in_2/Variable/Adam_1
#
# import/in_2/Variable_1/Adam
#
# import/in_2/Variable_1/Adam_1
#
# import/in_3/Variable/Adam
#
# import/in_3/Variable/Adam_1
#
# import/in_3/Variable_1/Adam
#
# import/in_3/Variable_1/Adam_1
#
# import/out_3/Variable/Adam
#
# import/out_3/Variable/Adam_1
#
# import/out_3/Variable_1/Adam
#
# import/out_3/Variable_1/Adam_1
#
# import_1/in/Variable
#
# import_1/in/Variable_1
#
# import_1/BasicRNNCell/Linear/Matrix
#
# import_1/BasicRNNCell/Linear/Bias
#
# import_1/out/Variable
#
# import_1/out/Variable_1
#
# import_1/in_1/Variable
#
# import_1/in_1/Variable_1
#
# import_1/out_1/Variable
#
# import_1/out_1/Variable_1
#
# import_1/in_2/Variable
#
# import_1/in_2/Variable_1
#
# import_1/out_2/Variable
#
# import_1/out_2/Variable_1
#
# import_1/in_3/Variable
#
# import_1/in_3/Variable_1
#
# import_1/out_3/Variable
#
# import_1/out_3/Variable_1
#
# import_1/beta1_power
#
# import_1/beta2_power
#
# import_1/in/Variable/Adam
#
# import_1/in/Variable/Adam_1
#
# import_1/in/Variable_1/Adam
#
# import_1/in/Variable_1/Adam_1
#
# import_1/BasicRNNCell/Linear/Matrix/Adam
#
# import_1/BasicRNNCell/Linear/Matrix/Adam_1
#
# import_1/BasicRNNCell/Linear/Bias/Adam
#
# import_1/BasicRNNCell/Linear/Bias/Adam_1
#
# import_1/in_1/Variable/Adam
#
# import_1/in_1/Variable/Adam_1
#
# import_1/in_1/Variable_1/Adam
#
# import_1/in_1/Variable_1/Adam_1
#
# import_1/in_2/Variable/Adam
#
# import_1/in_2/Variable/Adam_1
#
# import_1/in_2/Variable_1/Adam
#
# import_1/in_2/Variable_1/Adam_1
#
# import_1/in_3/Variable/Adam
#
# import_1/in_3/Variable/Adam_1
#
# import_1/in_3/Variable_1/Adam
#
# import_1/in_3/Variable_1/Adam_1
#
# import_1/out_3/Variable/Adam
#
# import_1/out_3/Variable/Adam_1
#
# import_1/out_3/Variable_1/Adam
#
# import_1/out_3/Variable_1/Adam_1
#
# import_1/import/in/Variable
#
# import_1/import/in/Variable_1
#
# import_1/import/BasicRNNCell/Linear/Matrix
#
# import_1/import/BasicRNNCell/Linear/Bias
#
# import_1/import/out/Variable
#
# import_1/import/out/Variable_1
#
# import_1/import/in_1/Variable
#
# import_1/import/in_1/Variable_1
#
# import_1/import/out_1/Variable
#
# import_1/import/out_1/Variable_1
#
# import_1/import/in_2/Variable
#
# import_1/import/in_2/Variable_1
#
# import_1/import/out_2/Variable
#
# import_1/import/out_2/Variable_1
#
# import_1/import/in_3/Variable
#
# import_1/import/in_3/Variable_1
#
# import_1/import/out_3/Variable
#
# import_1/import/out_3/Variable_1
#
# import_1/import/beta1_power
#
# import_1/import/beta2_power
#
# import_1/import/in/Variable/Adam
#
# import_1/import/in/Variable/Adam_1
#
# import_1/import/in/Variable_1/Adam
#
# import_1/import/in/Variable_1/Adam_1
#
# import_1/import/BasicRNNCell/Linear/Matrix/Adam
#
# import_1/import/BasicRNNCell/Linear/Matrix/Adam_1
#
# import_1/import/BasicRNNCell/Linear/Bias/Adam
#
# import_1/import/BasicRNNCell/Linear/Bias/Adam_1
#
# import_1/import/in_1/Variable/Adam
#
# import_1/import/in_1/Variable/Adam_1
#
# import_1/import/in_1/Variable_1/Adam
#
# import_1/import/in_1/Variable_1/Adam_1
#
# import_1/import/in_2/Variable/Adam
#
# import_1/import/in_2/Variable/Adam_1
#
# import_1/import/in_2/Variable_1/Adam
#
# import_1/import/in_2/Variable_1/Adam_1
#
# import_1/import/in_3/Variable/Adam
#
# import_1/import/in_3/Variable/Adam_1
#
# import_1/import/in_3/Variable_1/Adam
#
# import_1/import/in_3/Variable_1/Adam_1
#
# import_1/import/out_3/Variable/Adam
#
# import_1/import/out_3/Variable/Adam_1
#
# import_1/import/out_3/Variable_1/Adam
#
# import_1/import/out_3/Variable_1/Adam_1

# %%
with graph_new1.as_default():
    new_graph_def2 = graph_new1.as_graph_def()
    for node in new_graph_def2.node:
        if node.op == 'Variable':
            print(node)
        
        #restored_vars.append(RestoredVariable(node.name, trainable=trainable, collections=collections))
# Out:
# name: "in/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Matrix"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Bias"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "beta1_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "beta2_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Matrix/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Matrix/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Bias/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Bias/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Matrix"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Bias"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/beta1_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/beta2_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Matrix/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Matrix/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Bias/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Bias/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }

# %%
new_graph_def = graph_new1.as_graph_def()
for node in new_graph_def.node:
    if node.op == 'Variable':
        print(node)
# Out:
# name: "in/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Matrix"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Bias"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "beta1_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "beta2_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Matrix/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Matrix/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Bias/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "BasicRNNCell/Linear/Bias/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_1/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_2/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "in_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Matrix"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Bias"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_1/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_1/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_2/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_2/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable_1"
# op: "Variable"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/beta1_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/beta2_power"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Matrix/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Matrix/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Matrix"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Bias/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/BasicRNNCell/Linear/Bias/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/BasicRNNCell/Linear/Bias"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_1/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_1/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_2/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_2/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/in_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/in_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable_1/Adam"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "import/out_3/Variable_1/Adam_1"
# op: "Variable"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@import/out_3/Variable_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 2
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
